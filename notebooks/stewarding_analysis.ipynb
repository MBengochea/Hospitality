# %% [markdown]
# # Stewarding & Dishwashing Process Optimization
# **Portfolio disclaimer:** synthetic data and simulated/modelled outputs only. No real hotel results are claimed.

# %% [markdown]
# ## MEASURE → ANALYZE → PREDICT → IMPROVE → MONITOR
# The notebook emphasises operational interpretation and bounded improvement tests.

# %%
from pathlib import Path
import sys
ROOT=Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
sys.path.insert(0,str(ROOT))
import pandas as pd
import matplotlib.pyplot as plt
from src.models import train_stewarding_models
df=pd.read_csv(ROOT/"data/synthetic/stewarding_operations.csv",parse_dates=["date"])
df.head()

# %%
summary=df.groupby("meal_period").agg(items=("number_of_items","sum"),avg_wait=("waiting_time_minutes","mean"),utilisation=("dishwasher_utilization","mean"),rejects=("items_rejected","sum"))
summary.round(3)

# %%
summary[["avg_wait","utilisation"]].plot(kind="bar",subplots=True)
plt.suptitle("Synthetic stewarding flow indicators")
plt.tight_layout(); plt.show()

# %%
reg,clf,reg_metrics,clf_metrics,daily=train_stewarding_models(df)
reg_metrics,{k:v for k,v in clf_metrics.items() if k!="Confusion matrix"},clf_metrics["Confusion matrix"]

# %% [markdown]
# ## Operational action
# Use forecasts to plan capacity and prioritise supervisor attention. Test one change, protect quality/hygiene, and record a real post-test result before claiming improvement.
